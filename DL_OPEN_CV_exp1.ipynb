# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Raghavi/DeepLearning-codes/blob/main/DL_OPEN_CV_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
img = cv2.imread('/content/dog.jpg')
img
# Out:
# array([[[  0,  12,   4],
#         [  0,  14,   6],
#         [  3,  16,   8],
#         ...,
#         [  2,   6,   1],
#         [  2,   6,   1],
#         [  2,   6,   1]],
#
#        [[  0,  13,   5],
#         [  0,  15,   7],
#         [  3,  16,   8],
#         ...,
#         [  2,   6,   1],
#         [  2,   6,   1],
#         [  2,   6,   1]],
#
#        [[  0,  16,   5],
#         [  1,  17,   6],
#         [  4,  18,   7],
#         ...,
#         [  3,   7,   2],
#         [  3,   7,   2],
#         [  3,   7,   2]],
#
#        ...,
#
#        [[  5,  35,  30],
#         [  0,  37,  40],
#         [ 21,  90, 109],
#         ...,
#         [ 60, 122, 186],
#         [ 29,  84, 141],
#         [ 34,  83, 133]],
#
#        [[ 25,  53,  47],
#         [  0,  39,  38],
#         [  1,  70,  85],
#         ...,
#         [ 42, 109, 178],
#         [ 54, 115, 177],
#         [ 61, 117, 172]],
#
#        [[ 41,  70,  61],
#         [  3,  45,  44],
#         [  0,  59,  72],
# ...

# %%
print(img.shape)
print(img.size)
print(img)
# Out:
# (180, 231, 3)
# 124740
# [[[  0  12   4]
#   [  0  14   6]
#   [  3  16   8]
#   ...
#   [  2   6   1]
#   [  2   6   1]
#   [  2   6   1]]
#
#  [[  0  13   5]
#   [  0  15   7]
#   [  3  16   8]
#   ...
#   [  2   6   1]
#   [  2   6   1]
#   [  2   6   1]]
#
#  [[  0  16   5]
#   [  1  17   6]
#   [  4  18   7]
#   ...
#   [  3   7   2]
#   [  3   7   2]
#   [  3   7   2]]
#
#  ...
#
#  [[  5  35  30]
#   [  0  37  40]
#   [ 21  90 109]
#   ...
#   [ 60 122 186]
#   [ 29  84 141]
#   [ 34  83 133]]
#
#  [[ 25  53  47]
#   [  0  39  38]
#   [  1  70  85]
#   ...
#   [ 42 109 178]
#   [ 54 115 177]
#   [ 61 117 172]]
#
#  [[ 41  70  61]
#   [  3  45  44]
#   [  0  59  72]
#   ...
#   [ 38 107 177]
#   [ 79 141 205]
#   [ 78 136 195]]]

# %%
import cv2
img1 = cv2.imread('/content/dog.jpg',0)
img1
# Out:
# array([[  8,  10,  12, ...,   4,   4,   4],
#        [  9,  11,  12, ...,   4,   4,   4],
#        [ 11,  12,  13, ...,   5,   5,   5],
#        ...,
#        [ 30,  33,  88, ..., 134,  95,  92],
#        [ 48,  34,  67, ..., 122, 127, 127],
#        [ 64,  40,  55, ..., 120, 153, 147]], dtype=uint8)

# %%
print(img1.shape)
print(img1.size)
print(img1)
# Out:
# (180, 231)
# 41580
# [[  8  10  12 ...   4   4   4]
#  [  9  11  12 ...   4   4   4]
#  [ 11  12  13 ...   5   5   5]
#  ...
#  [ 30  33  88 ... 134  95  92]
#  [ 48  34  67 ... 122 127 127]
#  [ 64  40  55 ... 120 153 147]]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=231x180>
# <PIL.Image.Image image mode=L size=231x180>

# %%
resized_img1 = cv2.resize(img1,(500,400)) # Assign the resized image to 'resized_img'
cv2_imshow(resized_img1)
print(resized_img1.shape)
print(resized_img1.size)
# Out:
# <PIL.Image.Image image mode=L size=500x400>
# (400, 500)
# 200000

# %%
resized_img = cv2.resize(img,(300,300)) # Assign the resized image to 'resized_img'
cv2_imshow(resized_img)
print(resized_img.shape)
print(resized_img.size)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
# (300, 300, 3)
# 270000

# %%
#exp 1.1 reading the image using open cv
import cv2
image = cv2.imread('/content/bear.jpg')#color image
print(image.shape)
print(image.size)
print(image)
# Out:
# (180, 259, 3)
# 139860
# [[[255 233 153]
#   [252 229 149]
#   [249 226 146]
#   ...
#   [246 222 126]
#   [246 222 122]
#   [242 218 118]]
#
#  [[255 232 154]
#   [250 227 147]
#   [247 224 146]
#   ...
#   [238 213 111]
#   [241 217 111]
#   [240 216 110]]
#
#  [[254 231 155]
#   [250 228 150]
#   [247 224 148]
#   ...
#   [245 216 101]
#   [246 222 103]
#   [246 222 103]]
#
#  ...
#
#  [[106 205 125]
#   [ 94 205 113]
#   [ 63 194  79]
#   ...
#   [ 48 189  86]
#   [ 40 194  89]
#   [ 44 196  97]]
#
#  [[102 204 122]
#   [ 75 189  95]
#   [ 54 187  71]
#   ...
#   [ 42 183  80]
#   [ 56 210 105]
#   [ 66 218 119]]
#
#  [[ 82 186 103]
#   [ 64 178  84]
#   [ 58 191  75]
#   ...
#   [ 37 179  74]
#   [ 70 224 119]
#   [ 80 233 134]]]

# %%
#black and white
image1 = cv2.imread('/content/bear.jpg',0)
print(image1.shape)
print(image1.size)
print(image1)
# Out:
# (180, 259)
# 46620
# [[212 208 205 ... 196 195 191]
#  [211 206 203 ... 185 188 187]
#  [211 207 204 ... 185 189 189]
#  ...
#  [170 165 145 ... 142 145 149]
#  [168 148 137 ... 136 161 171]
#  [149 137 141 ... 131 175 186]]

# %%
#exp 1.2 display the image using open cv
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x180>

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=L size=259x180>

# %%
#exp 1.3 Resize the image using opencv
resize_image = cv2.resize(image,(400,300)) # Assign the resized image to 'resized_img'
print(resize_image.shape)
print(resize_image.size)
cv2_imshow(resize_image)
# Out:
# (300, 400, 3)
# 360000
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
resize_image1 = cv2.resize(image1,(400,300)) # Assign the resized image to 'resized_img'
print(resize_image1.shape)
print(resize_image1.size)
cv2_imshow(resize_image1)
# Out:
# (300, 400)
# 120000
# <PIL.Image.Image image mode=L size=400x300>
